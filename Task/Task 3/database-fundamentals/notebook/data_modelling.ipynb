# %%
import pandas as pd

df = pd.read_csv('../data/ecommerce_dataset.csv')
df.head()
# Out:
#    Order_Date      Time  Aging  Customer_Id  Gender Device_Type  \
# 0  2018-01-02  10:56:33    8.0        37077  Female         Web
# 1  2018-07-24  20:41:37    2.0        59173  Female         Web
# 2  2018-11-08  08:38:49    8.0        41066  Female         Web
# 3  2018-04-18  19:28:06    7.0        50741  Female         Web
# 4  2018-08-13  21:18:39    9.0        53639  Female         Web
#
#   Customer_Login_type    Product_Category            Product  Sales  Quantity  \
# 0              Member  Auto & Accessories  Car Media Players  140.0       1.0
# 1              Member  Auto & Accessories       Car Speakers  211.0       1.0
# 2              Member  Auto & Accessories    Car Body Covers  117.0       5.0
# 3              Member  Auto & Accessories    Car & Bike Care  118.0       1.0
# 4              Member  Auto & Accessories               Tyre  250.0       1.0
#
#    Discount  Profit  Shipping_Cost Order_Priority Payment_method
# ...

# %%
len(df)
# Out:
# 51290

# %%
df.columns
# Out:
# Index(['Order_Date', 'Time', 'Aging', 'Customer_Id', 'Gender', 'Device_Type',
#        'Customer_Login_type', 'Product_Category', 'Product', 'Sales',
#        'Quantity', 'Discount', 'Profit', 'Shipping_Cost', 'Order_Priority',
#        'Payment_method'],
#       dtype='object')

# %%
df.columns = [col.lower()  for col in df.columns]

# %%
df.drop_duplicates()
# Out:
#        order_date      time  aging  customer_id  gender device_type  \
# 0      2018-01-02  10:56:33    8.0        37077  Female         Web
# 1      2018-07-24  20:41:37    2.0        59173  Female         Web
# 2      2018-11-08  08:38:49    8.0        41066  Female         Web
# 3      2018-04-18  19:28:06    7.0        50741  Female         Web
# 4      2018-08-13  21:18:39    9.0        53639  Female         Web
# ...           ...       ...    ...          ...     ...         ...
# 51285  2018-02-28  22:59:50    6.0        78489  Female      Mobile
# 51286  2018-02-28  13:19:25    2.0        91941  Female      Mobile
# 51287  2018-02-28  10:25:07    6.0        63313    Male         Web
# 51288  2018-02-28  10:50:08    7.0        86485    Male         Web
# 51289  2018-02-28  11:09:40    5.0        81129    Male         Web
#
#       customer_login_type    product_category            product  sales  \
# 0                  Member  Auto & Accessories  Car Media Players  140.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_date           51290 non-null  object
#  1   time                 51290 non-null  object
#  2   aging                51289 non-null  float64
#  3   customer_id          51290 non-null  int64
#  4   gender               51290 non-null  object
#  5   device_type          51290 non-null  object
#  6   customer_login_type  51290 non-null  object
#  7   product_category     51290 non-null  object
#  8   product              51290 non-null  object
#  9   sales                51289 non-null  float64
#  10  quantity             51288 non-null  float64
#  11  discount             51289 non-null  float64
#  12  profit               51290 non-null  float64
#  13  shipping_cost        51289 non-null  float64
#  14  order_priority       51288 non-null  object
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['order_id'] = list(range(1, len(df) + 1))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_date           51290 non-null  datetime64[ns]
#  1   time                 51290 non-null  object
#  2   aging                51289 non-null  float64
#  3   customer_id          51290 non-null  int64
#  4   gender               51290 non-null  object
#  5   device_type          51290 non-null  object
#  6   customer_login_type  51290 non-null  object
#  7   product_category     51290 non-null  object
#  8   product              51290 non-null  object
#  9   sales                51289 non-null  float64
#  10  quantity             51288 non-null  float64
#  11  discount             51289 non-null  float64
#  12  profit               51290 non-null  float64
#  13  shipping_cost        51289 non-null  float64
#  14  order_priority       51288 non-null  object
# ...

# %%
# Customer Table
columns = ["customer_id", "gender"]
customer_df = df[columns].drop_duplicates().copy()
customer_df
# Out:
#        customer_id  gender
# 0            37077  Female
# 1            59173  Female
# 2            41066  Female
# 3            50741  Female
# 4            53639  Female
# ...            ...     ...
# 51285        78489  Female
# 51286        91941  Female
# 51287        63313    Male
# 51288        86485    Male
# 51289        81129    Male
#
# [44022 rows x 2 columns]

# %%
customer_df['customer_id'].value_counts()
# Out:
# customer_id
# 78520    2
# 99052    2
# 61815    2
# 73560    2
# 98750    2
#         ..
# 58953    1
# 46593    1
# 23865    1
# 22636    1
# 81129    1
# Name: count, Length: 38997, dtype: int64

# %%
customer_df[customer_df['customer_id'] == 71173]
# Out:
#        customer_id  gender
# 36874        71173  Female
# 46473        71173    Male

# %%
len(customer_df)
# Out:
# 44022

# %%
customer_df.nunique()
# Out:
# customer_id    38997
# gender             2
# dtype: int64

# %%
# Orders Table
columns = ["customer_id", "order_date", "order_priority", "payment_method","device_type", "customer_login_type"]
order_df = df[columns].copy()
order_df
# Out:
#        customer_id order_date order_priority payment_method device_type  \
# 0            37077 2018-01-02         Medium    credit_card         Web
# 1            59173 2018-07-24         Medium    credit_card         Web
# 2            41066 2018-11-08       Critical    credit_card         Web
# 3            50741 2018-04-18           High    credit_card         Web
# 4            53639 2018-08-13       Critical    credit_card         Web
# ...            ...        ...            ...            ...         ...
# 51285        78489 2018-02-28         Medium    money_order      Mobile
# 51286        91941 2018-02-28         Medium    credit_card      Mobile
# 51287        63313 2018-02-28         Medium    credit_card         Web
# 51288        86485 2018-02-28         Medium    credit_card         Web
# 51289        81129 2018-02-28         Medium    credit_card         Web
#
#       customer_login_type
# 0                  Member
# 1                  Member
# ...

# %%
order_df.nunique()
# Out:
# customer_id            38997
# order_date               356
# order_priority             4
# payment_method             5
# device_type                2
# customer_login_type        4
# dtype: int64

# %%
columns = ["product_category", "product"]
product_df = df[columns]
unique_product_df = product_df.drop_duplicates().copy()
unique_product_df['product_id'] = list(range(1, len(unique_product_df) + 1))
unique_product_df
# Out:
#          product_category                 product  product_id
# 0      Auto & Accessories       Car Media Players           1
# 1      Auto & Accessories            Car Speakers           2
# 2      Auto & Accessories         Car Body Covers           3
# 3      Auto & Accessories         Car & Bike Care           4
# 4      Auto & Accessories                    Tyre           5
# 5      Auto & Accessories              Bike Tyres           6
# 6      Auto & Accessories                 Car Mat           7
# 7      Auto & Accessories         Car Seat Covers           8
# 8      Auto & Accessories  Car Pillow & Neck Rest           9
# 5129              Fashion                  Shirts          10
# 5130              Fashion                   Jeans          11
# 5131              Fashion                   Suits          12
# 5132              Fashion             Sports Wear          13
# 5133              Fashion            Casula Shoes          14
# ...

# %%
product_df.nunique()
# Out:
# product_category     4
# product             42
# dtype: int64

# %%
unique_product_df.nunique()
# Out:
# product_category     4
# product             42
# product_id          42
# dtype: int64

# %%
len(unique_product_df)
# Out:
# 42

# %%
# OrderItems Table
columns = ["quantity","discount","sales","profit","shipping_cost","product","order_id"]
orderitems_df = df[columns]
orderitems_df

data = pd.merge(orderitems_df,unique_product_df)
data
# Out:
#        quantity  discount  sales  profit  shipping_cost            product  \
# 0           1.0       0.3  140.0    46.0            4.6  Car Media Players
# 1           1.0       0.3  211.0   112.0           11.2       Car Speakers
# 2           5.0       0.1  117.0    31.2            3.1    Car Body Covers
# 3           1.0       0.3  118.0    26.2            2.6    Car & Bike Care
# 4           1.0       0.3  250.0   160.0           16.0               Tyre
# ...         ...       ...    ...     ...            ...                ...
# 51285       4.0       0.3  124.0    19.2            1.9          Shoe Rack
# 51286       5.0       0.2   70.0    14.0            1.4          Umbrellas
# 51287       1.0       0.3  133.0    39.7            4.0    Dinner Crockery
# 51288       1.0       0.2  216.0   131.7           13.2        Sofa Covers
# 51289       5.0       0.3  211.0    99.4            9.9         Bed Sheets
#
#        order_id    product_category  product_id
# ...

# %%
orderitems_df.nunique()
# Out:
# quantity             5
# discount             5
# sales               39
# profit             391
# shipping_cost      153
# product             42
# order_id         51290
# dtype: int64

# %%
data = orderitems_df.drop_duplicates()
data
# Out:
#        quantity  discount  sales  profit  shipping_cost            product  \
# 0           1.0       0.3  140.0    46.0            4.6  Car Media Players
# 1           1.0       0.3  211.0   112.0           11.2       Car Speakers
# 2           5.0       0.1  117.0    31.2            3.1    Car Body Covers
# 3           1.0       0.3  118.0    26.2            2.6    Car & Bike Care
# 4           1.0       0.3  250.0   160.0           16.0               Tyre
# ...         ...       ...    ...     ...            ...                ...
# 51285       4.0       0.3  124.0    19.2            1.9          Shoe Rack
# 51286       5.0       0.2   70.0    14.0            1.4          Umbrellas
# 51287       1.0       0.3  133.0    39.7            4.0    Dinner Crockery
# 51288       1.0       0.2  216.0   131.7           13.2        Sofa Covers
# 51289       5.0       0.3  211.0    99.4            9.9         Bed Sheets
#
#        order_id
# 0             1
# 1             2
# ...
